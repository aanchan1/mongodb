# %% [markdown]
# <a href="https://colab.research.google.com/github/aanchan1/mongodb/blob/main/Mongodb_studentdatabase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dnspython
!-m pip install pymongo[srv]
# Out:
# ...
# /bin/bash: - : invalid option
# Usage:	/bin/bash [GNU long option] [option] ...
# 	/bin/bash [GNU long option] [option] script-file ...
# GNU long options:
# 	--debug
# 	--debugger
# 	--dump-po-strings
# 	--dump-strings
# 	--help
# 	--init-file
# 	--login
# 	--noediting
# 	--noprofile
# 	--norc
# 	--posix
# 	--rcfile
# 	--restricted
# 	--verbose
# 	--version
# Shell options:
# 	-ilrsD or -c command or -O shopt_option		(invocation only)
# 	-abefhkmnptuvxBCHP or -o option

# %%
import pandas as pd
df=pd.read_json("students.json",lines=True)
df
# Out:
#      _id              name                                             scores
# 0      0        aimee Zank  [{'score': 1.463179736705023, 'type': 'exam'},...
# 1      1  Aurelia Menendez  [{'score': 60.06045071030959, 'type': 'exam'},...
# 2      2       Corliss Zuk  [{'score': 67.03077096065002, 'type': 'exam'},...
# 3      3        Bao Ziglar  [{'score': 71.64343899778332, 'type': 'exam'},...
# 4      4  Zachary Langlais  [{'score': 78.68385091304332, 'type': 'exam'},...
# ..   ...               ...                                                ...
# 195  195     Linnie Weigel  [{'score': 52.44578368517977, 'type': 'exam'},...
# 196  196  Santiago Dollins  [{'score': 52.04052571137036, 'type': 'exam'},...
# 197  197     Tonisha Games  [{'score': 38.51269589995049, 'type': 'exam'},...
# 198  198    Timothy Harrod  [{'score': 11.9075674046519, 'type': 'exam'}, ...
# 199  199        Rae Kohout  [{'score': 82.11742562118049, 'type': 'exam'},...
#
# [200 rows x 3 columns]

# %%
df['scores'][0]
# Out:
# [{'score': 1.463179736705023, 'type': 'exam'},
#  {'score': 11.78273309957772, 'type': 'quiz'},
#  {'score': 35.8740349954354, 'type': 'homework'}]

# %%
df['scores'][0][0]["score"]
# Out:
# 1.463179736705023

# %%
df['scores'][0][1]["score"]
# Out:
# 11.78273309957772

# %%
df['scores'][0][2]["score"]
# Out:
# 35.8740349954354

# %%
exam=[]
quiz=[]
homework=[]
for i in range(0,len(df)):
  exam.append(df['scores'][i][0]["score"])
  quiz.append(df['scores'][i][1]["score"])
  homework.append(df['scores'][i][2]["score"])
df['Exam']=exam
df['Quiz']=quiz
df['Homework']=homework
df
# Out:
#      _id              name                                             scores  \
# 0      0        aimee Zank  [{'score': 1.463179736705023, 'type': 'exam'},...
# 1      1  Aurelia Menendez  [{'score': 60.06045071030959, 'type': 'exam'},...
# 2      2       Corliss Zuk  [{'score': 67.03077096065002, 'type': 'exam'},...
# 3      3        Bao Ziglar  [{'score': 71.64343899778332, 'type': 'exam'},...
# 4      4  Zachary Langlais  [{'score': 78.68385091304332, 'type': 'exam'},...
# ..   ...               ...                                                ...
# 195  195     Linnie Weigel  [{'score': 52.44578368517977, 'type': 'exam'},...
# 196  196  Santiago Dollins  [{'score': 52.04052571137036, 'type': 'exam'},...
# 197  197     Tonisha Games  [{'score': 38.51269589995049, 'type': 'exam'},...
# 198  198    Timothy Harrod  [{'score': 11.9075674046519, 'type': 'exam'}, ...
# 199  199        Rae Kohout  [{'score': 82.11742562118049, 'type': 'exam'},...
#
# ...

# %%
df.drop(['scores'],axis=1,inplace=True)
df.drop(['_id'],axis=1,inplace=True)
df['Total']=df.iloc[:,1:4].sum(axis=1)
df['Percentage']=df.iloc[:,1:4].mean(axis=1)
df
# Out:
#                  name       Exam       Quiz   Homework       Total  Percentage
# 0          aimee Zank   1.463180  11.782733  35.874035   49.119948   16.373316
# 1    Aurelia Menendez  60.060451  52.797907  71.761334  184.619692   61.539897
# 2         Corliss Zuk  67.030771   6.301852  66.283447  139.616069   46.538690
# 3          Bao Ziglar  71.643439  24.802213  42.261471  138.707123   46.235708
# 4    Zachary Langlais  78.683851  90.296310  34.416201  203.396363   67.798788
# ..                ...        ...        ...        ...         ...         ...
# 195     Linnie Weigel  52.445784  90.777505  11.750084  154.973373   51.657791
# 196  Santiago Dollins  52.040526  33.633001  78.792574  164.466100   54.822033
# 197     Tonisha Games  38.512696  31.162876  79.158564  148.834135   49.611378
# 198    Timothy Harrod  11.907567  20.518800  64.856504   97.282871   32.427624
# 199        Rae Kohout  82.117426  49.612955  28.868237  160.598617   53.532872
#
# [200 rows x 6 columns]

# %%
import pymongo
from pymongo import MongoClient
client = pymongo.MongoClient("mongodb+srv://datascience:jjjjaaaa@cluster0.nlhi0.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.test

# %%
db=client.get_database('studentdatabase')
records=db.studentdatabase
records.count_documents({})
# Out:
# 0

# %%
for i in range(len(df)):
  a=df.iloc[i].to_dict()
  records.insert_one(a)

# %% [markdown]
#  1)Find the student name who scored maximum scores in all (exam, quiz and homework)?

# %%
highestmark=records.find().sort("Total",-1).limit(1)
for x in highestmark:
  print(x)
# Out:
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb1a'), 'name': 'Jessika Dagenais', 'Exam': 90.47179954427436, 'Quiz': 90.3001402468489, 'Homework': 95.17753772405909, 'Total': 275.94947751518237, 'Percentage': 91.98315917172745}

# %% [markdown]
# 2)      Find students who scored below average in the exam and pass mark is 40%?

# %%
belowaverage=records.find({"Exam": {"$gte":40, "$lte":50}})
for x in belowaverage:
  print(x)
# Out:
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb12'), 'name': 'Wilburn Spiess', 'Exam': 44.87186330181261, 'Quiz': 25.72395114668016, 'Homework': 63.42288310628662, 'Total': 134.0186975547794, 'Percentage': 44.67289918492647}
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb17'), 'name': 'Denisha Cast', 'Exam': 45.61876862259409, 'Quiz': 98.35723209418343, 'Homework': 55.90835657173456, 'Total': 199.8843572885121, 'Percentage': 66.62811909617069}
# {'_id': ObjectId('623dcb97b4d05f2bd8fdeb20'), 'name': 'Gisela Levin', 'Exam': 44.51211101958831, 'Quiz': 0.6578497966368001, 'Homework': 93.36341655949683, 'Total': 138.53337737572195, 'Percentage': 46.17779245857398}
# {'_id': ObjectId('623dcb97b4d05f2bd8fdeb21'), 'name': 'Tressa Schwing', 'Exam': 42.17439799514388, 'Quiz': 71.99314840599558, 'Homework': 81.23972632069464, 'Total': 195.4072727218341, 'Percentage': 65.1357575739447}
# ...

# %% [markdown]
# 3)      Find students who scored below pass mark and assigned them as fail, and above pass mark as pass in all the categories.

# %%
pass_fail_details=records.aggregate(
   [
      {
         "$project":
           {
             "name": True ,
             "Exam":
               {
                 "$cond": [ { "$gte": [ "$Exam", 40 ] }, "Pass", "Fail" ]
               },
            "Quiz":
               {
                 "$cond": [ { "$gte": [ "$Quiz", 40 ] }, "Pass", "Fail" ]
               },
            "Homework":
               {
                 "$cond": [ { "$gte": [ "$Homework", 40 ] }, "Pass", "Fail" ]
               }
           }
      }
   ]
)
for k in pass_fail_details:
  print(k)
# Out:
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb0d'), 'name': 'aimee Zank', 'Exam': 'Fail', 'Quiz': 'Fail', 'Homework': 'Fail'}
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb0e'), 'name': 'Aurelia Menendez', 'Exam': 'Pass', 'Quiz': 'Pass', 'Homework': 'Pass'}
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb0f'), 'name': 'Corliss Zuk', 'Exam': 'Pass', 'Quiz': 'Fail', 'Homework': 'Pass'}
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb10'), 'name': 'Bao Ziglar', 'Exam': 'Pass', 'Quiz': 'Fail', 'Homework': 'Pass'}
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb11'), 'name': 'Zachary Langlais', 'Exam': 'Pass', 'Quiz': 'Pass', 'Homework': 'Fail'}
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb12'), 'name': 'Wilburn Spiess', 'Exam': 'Pass', 'Quiz': 'Fail', 'Homework': 'Pass'}
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb13'), 'name': 'Jenette Flanders', 'Exam': 'Fail', 'Quiz': 'Fail', 'Homework': 'Pass'}
# ...

# %% [markdown]
# 4)       Find the total and average of the exam, quiz and homework and store them in a separate collection.

# %%
total_avg=records.aggregate(
   [
      {
         "$project":
           {
             "name": True ,
             'total' : { '$add' : [ '$Exam', '$Quiz',"$Homework" ]
              },
            'average': { '$avg' : [ '$Exam', '$Quiz',"$Homework" ]
              }
           }
      }
   ]
)
for k in total_avg:
  print(k)
# Out:
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb0d'), 'name': 'aimee Zank', 'total': 49.11994783171814, 'average': 16.373315943906046}
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb0e'), 'name': 'Aurelia Menendez', 'total': 184.61969202100374, 'average': 61.53989734033458}
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb0f'), 'name': 'Corliss Zuk', 'total': 139.61606947126907, 'average': 46.53868982375636}
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb10'), 'name': 'Bao Ziglar', 'total': 138.70712252233457, 'average': 46.23570750744486}
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb11'), 'name': 'Zachary Langlais', 'total': 203.3963625302728, 'average': 67.79878751009093}
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb12'), 'name': 'Wilburn Spiess', 'total': 134.0186975547794, 'average': 44.67289918492647}
# {'_id': ObjectId('623dcb96b4d05f2bd8fdeb13'), 'name': 'Jenette Flanders', 'total': 147.2203575476617, 'average': 49.07345251588723}
# ...

# %% [markdown]
# 5)      Create a new collection which consists of students who scored below average and above 40% in all the categories.

# %%
below_avg_above_pass=[]
for i in records.find({"$and":[{'Exam':{"$gte":40,"$lt":50}},{'Quiz':{"$gte":40,"$lt":50}},{'Homework':{"$gte":40,"$lt":50}}]}):
  below_avg_above_pass.append(i)
print(below_avg_above_pass)
# Out:
# []

# %% [markdown]
# There are no records with students who scored below average(50) and above 40%

# %% [markdown]
# 6)      Create a new collection which consists of students who scored below the fail mark in all the categories.

# %%
fail_mark=[]
for i in records.find({"$and":[{'Exam':{"$lt":40}},{'Quiz':{"$lt":40}},{'Homework':{"$lt":40}}]}):

  fail_mark.append(i)
fail_mark
# Out:
# [{'Exam': 1.463179736705023,
#   'Homework': 35.8740349954354,
#   'Percentage': 16.373315943906046,
#   'Quiz': 11.78273309957772,
#   'Total': 49.11994783171814,
#   '_id': ObjectId('623dcb96b4d05f2bd8fdeb0d'),
#   'name': 'aimee Zank'}]

# %% [markdown]
# 7)      Create a new collection which consists of students who scored above pass mark in all the categories.

# %%
passed=[]

for i in records.find({"$and":[{'Exam':{"$gte":40}},{'Quiz':{"$gte":40}},{'Homework':{"$gte":40}}]}).sort('Percentage',-1):
  passed.append(i)
    
passed
# Out:
# [{'Exam': 90.47179954427436,
#   'Homework': 95.17753772405909,
#   'Percentage': 91.98315917172745,
#   'Quiz': 90.3001402468489,
#   'Total': 275.94947751518237,
#   '_id': ObjectId('623dcb96b4d05f2bd8fdeb1a'),
#   'name': 'Jessika Dagenais'},
#  {'Exam': 89.61845831842888,
#   'Homework': 96.57912148645883,
#   'Percentage': 89.54879045499759,
#   'Quiz': 82.44879156010508,
#   'Total': 268.6463713649928,
#   '_id': ObjectId('623dcb99b4d05f2bd8fdeb4d'),
#   'name': 'Whitley Fears'},
#  {'Exam': 80.59006098671075,
#   'Homework': 93.12134003887978,
#   'Percentage': 88.99859407182413,
#   'Quiz': 93.28438118988183,
#   'Total': 266.9957822154724,
#   '_id': ObjectId('623dcb98b4d05f2bd8fdeb41'),
#   'name': 'Tawana Oberg'},
#  {'Exam': 96.93459855769822,
#   'Homework': 70.7887302106597,
#   'Percentage': 87.79965530755887,
#   'Quiz': 95.6756371543187,
#   'Total': 263.3989659226766,
#   '_id': ObjectId('623dcb9cb4d05f2bd8fdeb8c'),
#   'name': 'Jessika Dagenais'},
# ...
